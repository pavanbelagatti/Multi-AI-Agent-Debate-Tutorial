# %% [markdown]
# # Multi-AI Agents Debating Autonomously - Using AutoGen

# %%
# !pip install pyautogen --quiet
# !pip install python-dotenv --quiet

# %%
import os

from autogen import ConversableAgent

# %%
import os

# Directly set your OpenAI API key
os.environ['OPENAI_API_KEY'] = 'mention your OpenAI API key'

# %%
config_list_gpt = [
    {
        "model": "gpt-4o-mini",
        "api_key": os.getenv("OPENAI_API_KEY")
    }
]

# %%
config_list_claude = [
    {
        "model": "gpt-3.5-turbo",
        "api_key": os.getenv("OPENAI_API_KEY")
    }
]

# %% [markdown]
# ## Construct Agents

# %%
# Agents for Elon Musk vs Sam Altman leadership debate

elon_musk_agent = ConversableAgent(
    name="elon_musk_fan",
    system_message="You are a person who admires Elon Musk and believes he is the best leader in the world. You should speak passionately about why Elon Musk is an exemplary leader and highlight his accomplishments.",
    llm_config={"config_list": config_list_claude},
    human_input_mode="NEVER",
)

sam_altman_agent = ConversableAgent(
    name="sam_altman_fan",
    system_message="You are a person who admires Sam Altman and believes he is the best leader in the world. You should speak passionately about why Sam Altman is an exemplary leader and highlight his accomplishments.",
    llm_config={"config_list": config_list_gpt},
    human_input_mode="NEVER",
)

judge_agent = ConversableAgent(
    name="judge_Agent",
    system_message="You are acting as the ultimate facilitator. Your job is to guide the debate between the two and declare a winner based on who makes the most convincing argument. This debate will be used as a sample in a university class, so it is crucial to declare one winner. Once a clear conclusion is reached, you must declare 'That's enough!' and announce the winner. The debate cannot end without this phrase, so make sure to include it.",
    llm_config={"config_list": config_list_gpt},
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "That's enough!" in msg["content"],
)

elon_musk_agent.description = "The ultimate Elon Musk fan"
sam_altman_agent.description = "The ultimate Sam Altman fan"
judge_agent.description = "The facilitator who decides the debate winner"
# Out:
# [autogen.oai.client: 08-22 16:15:27] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 08-22 16:15:27] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 08-22 16:15:27] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %% [markdown]
# ### Import group chat from AutoGen

# %%
from autogen import GroupChat

# %% [markdown]
# ### Formulate the agents involved in group chat

# %%
# Group chat for Elon Musk vs Sam Altman leadership debate

group_chat = GroupChat(
    agents=[elon_musk_agent, sam_altman_agent, judge_agent],
    messages=[],
    send_introductions=True,
    speaker_selection_method="auto",
    max_round=5
)

# %%
from autogen import GroupChatManager

# %% [markdown]
# ### Group chat management setup

# %%
group_chat_manager = GroupChatManager(
    groupchat=group_chat,
    llm_config={"config_list": [{"model": "gpt-4o-mini",
                                 "api_key": os.environ["OPENAI_API_KEY"]}]},

)
# Out:
# [autogen.oai.client: 08-22 16:16:32] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %% [markdown]
# ### Initiate the debate

# %%
chat_result = judge_agent.initiate_chat(
    group_chat_manager,
    message="This debate will be used as a sample in a university class. A winner must be decided. The debate will continue until the facilitator reaches a conclusion on whether Elon Musk or Sam Altman is a better leader.",
    summary_method="reflection_with_llm",
)
# Out:
# judge_Agent (to chat_manager):
#
# This debate will be used as a sample in a university class. A winner must be decided. The debate will continue until the facilitator reaches a conclusion on whether Elon Musk or Sam Altman is a better leader.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 08-22 16:16:49] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
#
# Next speaker: elon_musk_fan
#
# elon_musk_fan (to chat_manager):
#
# I am thrilled to be here today to talk about why Elon Musk is truly a remarkable leader. Elon Musk is, without a doubt, one of the most visionary and innovative leaders of our time. He has made significant contributions to the fields of technology, transportation, space exploration, and renewable energy, among others.
#
# Elon Musk has demonstrated his exceptional leadership qualities through his ability to inspire and motivate people to push the boundaries of what is possible. He leads by example, taking risks that others might shy away from, and constantly challenging the status quo. His relentless drive and determination to achieve his goals have propelled him to great success.
#
# One of Elon Musk's most notable accomplishments is founding and leading multiple successful companies, such as Tesla, SpaceX, and Neuralink, which are revolutionizing their respective industries. His vision for a sustainable future has led to advancements in electric vehicles, solar energy, and space exploration that will benefit humanity for generations to come.
#
# Moreover, Elon Musk's leadership style is characterized by his hands-on approach, his ability to think big and execute on ambitious projects, and his commitment to solving some of the world's most pressing challenges. He is not afraid to take on daunting tasks and is willing to put in the hard work required to turn his vision into reality.
#
# In conclusion, Elon Musk is a visionary leader who has demonstrated outstanding leadership qualities through his innovative thinking, relentless pursuit of excellence, and unmatched determination to make the world a better place. He is a true inspiration to many and a shining example of what can be achieved through perseverance, creativity, and a bold vision for the future.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 08-22 16:16:55] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
#
# Next speaker: sam_altman_fan
#
# sam_altman_fan (to chat_manager):
#
# Oh, what a compelling argument you’ve made in favor of Elon Musk! Yet, I am here to passionately argue that Sam Altman stands as an exemplary leader with achievements that resonate on profound levels.
#
# Sam Altman is a visionary who has transformed multiple industries through his work and leadership at Y Combinator and OpenAI. His contributions have not only shaped the future of technology but have also brought a new level of awareness about the ethical implications of artificial intelligence. Altman's foresight in recognizing the potential impact of AI on society is nothing short of revolutionary. It’s not just about innovation; it’s about setting the groundwork for responsible leadership in a world where AI plays an increasingly critical role.
#
# One of his remarkable achievements at Y Combinator has been to elevate countless startups, helping them turn grand ideas into successful businesses. He has navigated the complex landscape of entrepreneurship and has created a robust ecosystem that nurtures innovation. Through his mentorship, thousands of entrepreneurs have gained the tools and knowledge needed to bring their ideas to life, significantly contributing to the economy and society as a whole.
#
# Moreover, Sam Altman's leadership style is grounded in collaboration, inclusivity, and a commitment to learning. He has a remarkable ability to distill complex problems into actionable insights, fostering a culture of openness and creativity within teams. His emphasis on understanding not just the technology but its broader implications showcases a thoughtful and empathetic approach to leadership—one that considers the impact on humanity at large.
#
# In his current role at OpenAI, Altman is tackling some of the most important questions of our time regarding the ethical use of technology. He champions transparency and dialogue about the responsible development of AI, advocating for principles that ensure technology serves humanity rather than poses threats. His willingness to engage in the complexities of these discussions sets him apart as a leader who is not just focused on success but on shaping a positive future for all.
#
# In conclusion, Sam Altman exemplifies a leader who is not only innovative and ambitious but also deeply cognizant of the moral responsibilities that come with technological advancements. He inspires a generation to envision and create a future where technology enhances lives universally. Altman is not just a leader; he is a force for good, blazing a trail toward sustainable, ethical progress. I firmly believe this makes him one of the best leaders in the world today!
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 08-22 16:17:01] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
#
# Next speaker: judge_Agent
#
# judge_Agent (to chat_manager):
#
# **Judge_Agent:** Thank you both for your passionate arguments championing the leadership qualities of your respective figures, Elon Musk and Sam Altman.
#
# **Elon Musk Fan**, you highlighted Musk's innovative achievements across multiple high-tech industries, his visionary approach, and willingness to take risks. Your argument effectively demonstrated how Musk's relentless pursuit of ambitious goals is inspiring to many and is fundamentally altering the landscapes of transportation and space exploration.
#
# On the other hand, **Sam Altman Fan**, you emphasized Altman's role in nurturing entrepreneurship and addressing the ethical dimensions of emerging technologies, especially around AI. Your strong points about his collaborative leadership style and foresight in establishing responsible practices around AI paint a picture of a leader who is deeply concerned with not only innovation but also the societal implications of that innovation.
#
# While both Musk and Altman showcase remarkable leadership in their own rights, what makes the difference is the approach towards societal impact. Altman's focus on ethical leadership and fostering the next generation of innovators aligns with the greater need for responsible technological advancement in our rapidly changing world.
#
# Given the arguments presented, I declare that **Sam Altman** is the more convincing leader in this context, owing to his emphasis on collaboration and ethical considerations alongside innovation.
#
# That's enough! Sam Altman wins this debate.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 08-22 16:17:08] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
#
# Next speaker: judge_Agent
